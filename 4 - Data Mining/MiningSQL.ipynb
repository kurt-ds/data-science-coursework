# %% [markdown]
# # SQL Mining Assignment
#
# **Name:** Allen Kurt Delos Santos
#
# **Course & Section:** BSCS-ML - COM221

# %% [markdown]
# ### **Data Mining Using SQL**

# %% [markdown]
# <font color="red">File access required:</font> In Colab this notebook requires first uploading files **Shop.csv** and **Movies.csv** using the *Files* feature in the left toolbar. If running the notebook on a local computer, simply ensure these files are in the same workspace as the notebook.

# %%
# !pip install prettytable==0.7.2
# !pip install ipython-sql
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: prettytable==0.7.2 in c:\users\windows 11\appdata\roaming\python\python312\site-packages (0.7.2)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: ipython-sql in c:\users\windows 11\appdata\roaming\python\python312\site-packages (0.5.0)
# Requirement already satisfied: prettytable in c:\users\windows 11\appdata\roaming\python\python312\site-packages (from ipython-sql) (0.7.2)
# Requirement already satisfied: ipython in c:\anaconda3\lib\site-packages (from ipython-sql) (8.27.0)
# Requirement already satisfied: sqlalchemy>=2.0 in c:\anaconda3\lib\site-packages (from ipython-sql) (2.0.34)
# Requirement already satisfied: sqlparse in c:\users\windows 11\appdata\roaming\python\python312\site-packages (from ipython-sql) (0.5.5)
# Requirement already satisfied: six in c:\anaconda3\lib\site-packages (from ipython-sql) (1.16.0)
# Requirement already satisfied: ipython-genutils in c:\anaconda3\lib\site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\windows 11\appdata\roaming\python\python312\site-packages (from sqlalchemy>=2.0->ipython-sql) (4.13.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\anaconda3\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (3.0.1)
# Requirement already satisfied: decorator in c:\anaconda3\lib\site-packages (from ipython->ipython-sql) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\anaconda3\lib\site-packages (from ipython->ipython-sql) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\anaconda3\lib\site-packages (from ipython->ipython-sql) (2.15.1)
# Requirement already satisfied: stack-data in c:\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.2.0)
# Requirement already satisfied: traitlets>=5.13.0 in c:\anaconda3\lib\site-packages (from ipython->ipython-sql) (5.14.3)
# Requirement already satisfied: colorama in c:\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.4.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\anaconda3\lib\site-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.3)
# Requirement already satisfied: wcwidth in c:\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython->ipython-sql) (0.2.5)
# Requirement already satisfied: executing in c:\anaconda3\lib\site-packages (from stack-data->ipython->ipython-sql) (0.8.3)
# Requirement already satisfied: asttokens in c:\anaconda3\lib\site-packages (from stack-data->ipython->ipython-sql) (2.0.5)
# Requirement already satisfied: pure-eval in c:\anaconda3\lib\site-packages (from stack-data->ipython->ipython-sql) (0.2.2)

# %%
# Set-up
# %load_ext sql
# %sql sqlite://
import pandas as pd

# %%
# Load tables from CSV files
# Shop
with open('Shop.csv') as f: Shop = pd.read_csv(f, index_col=0)
# %sql drop table if exists Shop;
# %sql --persist Shop
# Movies
with open('Movies.csv') as f: Movies = pd.read_csv(f, index_col=0)
# %sql drop table if exists Movies;
# %sql --persist Movies
# Out:
#  * sqlite://
# Done.
#  * sqlite://
#  * sqlite://
# Done.
#  * sqlite://
# 'Persisted movies'

# %% [markdown]
# ## Shopping dataset - frequent item-sets

# %%
# %%sql
# select * from Shop
# Out:
#  * sqlite://
# Done.
# [(1, 'milk'),
#  (1, 'eggs'),
#  (1, 'juice'),
#  (2, 'milk'),
#  (2, 'juice'),
#  (2, 'cookies'),
#  (3, 'eggs'),
#  (3, 'chips'),
#  (4, 'milk'),
#  (4, 'eggs'),
#  (5, 'milk'),
#  (5, 'juice'),
#  (5, 'cookies'),
#  (5, 'chips')]

# %% [markdown]
# ### Frequent item-sets of two

# %% [markdown]
# #### All pairs of items occurring together

# %%
# %%sql
# select T1.item as item1, T2.item as item2
# from Shop T1, Shop T2
# where T1.TID = T2.TID
# and T1.item < T2.item
# Out:
#  * sqlite://
# Done.
# [('eggs', 'milk'),
#  ('eggs', 'juice'),
#  ('juice', 'milk'),
#  ('juice', 'milk'),
#  ('cookies', 'milk'),
#  ('cookies', 'juice'),
#  ('chips', 'eggs'),
#  ('eggs', 'milk'),
#  ('juice', 'milk'),
#  ('cookies', 'milk'),
#  ('cookies', 'juice'),
#  ('chips', 'milk'),
#  ('chips', 'juice'),
#  ('chips', 'cookies')]

# %% [markdown]
# #### Now with number of transactions they occur together in

# %%
# %%sql
# select T1.item as item1, T2.item as item2, count()
# from Shop T1, Shop T2
# where T1.TID = T2.TID
# and T1.item < T2.item
# group by T1.item, T2.item
# Out:
#  * sqlite://
# Done.
# [('chips', 'cookies', 1),
#  ('chips', 'eggs', 1),
#  ('chips', 'juice', 1),
#  ('chips', 'milk', 1),
#  ('cookies', 'juice', 2),
#  ('cookies', 'milk', 2),
#  ('eggs', 'juice', 1),
#  ('eggs', 'milk', 2),
#  ('juice', 'milk', 3)]

# %% [markdown]
# #### Total number of transactions

# %%
# %%sql
# select count(distinct TID) from Shop
# Out:
#  * sqlite://
# Done.
# [(5,)]

# %% [markdown]
# #### Put it together for frequent item-sets

# %%
support = .3
print(support)
# Out:
# 0.3

# %%
# %%sql
# select T1.item as item1, T2.item as item2
# from Shop T1, Shop T2
# where T1.TID = T2.TID
# and T1.item < T2.item
# group by T1.item, T2.item
# having 1.0*count() / (select count(distinct TID) from Shop) > :support
# Out:
#  * sqlite://
# Done.
# [('cookies', 'juice'),
#  ('cookies', 'milk'),
#  ('eggs', 'milk'),
#  ('juice', 'milk')]

# %% [markdown]
# ### Frequent item-sets of three

# %% [markdown]
# #### All triples of items occurring together

# %%
# %%sql
# select T1.item as item1, T2.item as item2, T3.item as item3
# from Shop T1, Shop T2, Shop T3
# where T1.TID = T2.TID and T2.TID = T3.TID
# and T1.item < T2.item and T2.item < T3.item
# Out:
#  * sqlite://
# Done.
# [('eggs', 'juice', 'milk'),
#  ('cookies', 'juice', 'milk'),
#  ('cookies', 'juice', 'milk'),
#  ('chips', 'juice', 'milk'),
#  ('chips', 'cookies', 'milk'),
#  ('chips', 'cookies', 'juice')]

# %% [markdown]
# #### Now with number of transactions they occur together in

# %%
# %%sql
# select distinct T1.item as item1, T2.item as item2, T3.item as item3, count()
# from Shop T1, Shop T2, Shop T3
# where T1.TID = T2.TID and T2.TID = T3.TID
# and T1.item < T2.item and T2.item < T3.item
# group by T1.item, T2.item, T3.item
# Out:
#  * sqlite://
# Done.
# [('chips', 'cookies', 'juice', 1),
#  ('chips', 'cookies', 'milk', 1),
#  ('chips', 'juice', 'milk', 1),
#  ('cookies', 'juice', 'milk', 2),
#  ('eggs', 'juice', 'milk', 1)]

# %% [markdown]
# #### Put it together for frequent item-sets

# %%
support = .3
print(support)
# Out:
# 0.3

# %%
# %%sql
# select T1.item as item1, T2.item as item2, T3.item as item3
# from Shop T1, Shop T2, Shop T3
# where T1.TID = T2.TID and T2.TID = T3.TID
# and T1.item < T2.item and T2.item < T3.item
# group by T1.item, T2.item, T3.item
# having 1.0*count() / (select count(distinct TID) from Shop) > :support
# Out:
#  * sqlite://
# Done.
# [('cookies', 'juice', 'milk')]

# %% [markdown]
# ### <font color = 'green'>**Your Turn - Movies dataset frequent item-sets**</font>

# %%
# %%sql
# select * from Movies limit 15
# Out:
#  * sqlite://
# Done.
# [(145755, 'The Fault in Our Stars'),
#  (145755, 'Boyhood'),
#  (145755, 'Big Hero 6'),
#  (145755, 'The Imitation Game'),
#  (145755, 'Inside Out'),
#  (117070, 'Inside Out'),
#  (239040, 'Inside Out'),
#  (177796, 'Gone Girl'),
#  (177796, 'Magic Mike XXL'),
#  (126875, 'The Imitation Game'),
#  (126875, 'Inside Out'),
#  (55295, 'The Imitation Game'),
#  (55295, 'Inside Out'),
#  (92094, 'The Fault in Our Stars'),
#  (92094, 'Boyhood')]

# %%
# %%sql
# select count(distinct TID) as numUsers,
#        count(distinct item) as numMovies
# from Movies
# Out:
#  * sqlite://
# Done.
# [(1382, 123)]

# %% [markdown]
# #### Mine for frequent item-sets of three and four items in the Movies dataset. Find a single support threshold where the number of frequent item-sets of three items is more than 10 but less than 20, and the number of frequent item-sets of four items is more than 0.

# %%
support = 0.03
print(support)
# Out:
# 0.03

# %%
# %%sql
# select T1.item as item1, T2.item as item2, T3.item as item3, count()
# from Movies T1, Movies T2, Movies T3
# where T1.TID = T2.TID and T2.TID = T3.TID
# and T1.item < T2.item and T2.item < T3.item
# group by T1.item, T2.item, T3.item
# having 1.0*count() / (select count(distinct TID) from Movies) > :support
# Out:
#  * sqlite://
# Done.
# [('Big Hero 6', 'Boyhood', 'Gone Girl', 56),
#  ('Big Hero 6', 'Boyhood', 'The Imitation Game', 57),
#  ('Big Hero 6', 'Fury', 'Gone Girl', 43),
#  ('Big Hero 6', 'Fury', 'The Imitation Game', 44),
#  ('Big Hero 6', 'Gone Girl', 'Inside Out', 85),
#  ('Big Hero 6', 'Gone Girl', 'The Imitation Game', 119),
#  ('Big Hero 6', 'Inside Out', 'The Imitation Game', 102),
#  ('Boyhood', 'Fury', 'Gone Girl', 43),
#  ('Boyhood', 'Fury', 'The Imitation Game', 43),
#  ('Boyhood', 'Gone Girl', 'Inside Out', 54),
#  ('Boyhood', 'Gone Girl', 'The Imitation Game', 95),
#  ('Boyhood', 'Inside Out', 'The Imitation Game', 52),
#  ('Fury', 'Gone Girl', 'The Imitation Game', 70),
#  ('Gone Girl', 'Inside Out', 'The Imitation Game', 103)]

# %%
# %%sql
# select T1.item as item1, T2.item as item2, T3.item as item3, T4.item as item4, count()
# from Movies T1, Movies T2, Movies T3, Movies T4
# where T1.TID = T2.TID and T2.TID = T3.TID and T3.TID = T4.TID
# and T1.item < T2.item and T2.item < T3.item and T3.item < T4.item
# group by T1.item, T2.item, T3.item, T4.item
# having 1.0*count() / (select count(distinct TID) from Movies) > :support
# Out:
#  * sqlite://
# Done.
# [('Big Hero 6', 'Boyhood', 'Gone Girl', 'The Imitation Game', 46),
#  ('Big Hero 6', 'Gone Girl', 'Inside Out', 'The Imitation Game', 59),
#  ('Boyhood', 'Gone Girl', 'Inside Out', 'The Imitation Game', 42)]

# %% [markdown]
# ## Shopping dataset - association rules

# %% [markdown]
# ### Association rules with one item on the left-hand side

# %%
support = .5
confidence = .5
print(support, confidence)
# Out:
# 0.5 0.5

# %% [markdown]
# #### First compute frequent item-sets of one item with specified support, as candidate left-hand sides of assocation rules; include number of transactions

# %%
# %%sql
# select item, count() as numtrans
# from Shop
# group by item
# having 1.0*count() / (select count(distinct TID) from Shop) > :support
# Out:
#  * sqlite://
# Done.
# [('eggs', 3), ('juice', 3), ('milk', 4)]

# %% [markdown]
# #### Do the same query but save the result in a table called "Frequents"

# %%
# %%sql
# drop table if exists Frequent;
# create table Frequent(item, numtrans);
# insert into Frequent
# select item, count()
# from Shop
# group by item
# having 1.0*count() / (select count(distinct TID) from Shop) > :support;
# select * from Frequent
# Out:
#  * sqlite://
# Done.
# Done.
# 3 rows affected.
# Done.
# [('eggs', 3), ('juice', 3), ('milk', 4)]

# %% [markdown]
# #### All pairs with frequent left-hand side, number of transactions for left-hand side, and number of transactions for both

# %%
# %%sql
# select T1.item as LHS, T2.item as RHS, F.numtrans as LHS_count, count() as both
# from Shop T1, Shop T2, Frequent F
# where T1.item = F.item
# and T1.TID = T2.TID
# and T1.item != T2.item
# group by T1.item, T2.item
# Out:
#  * sqlite://
# Done.
# [('eggs', 'chips', 3, 1),
#  ('eggs', 'juice', 3, 1),
#  ('eggs', 'milk', 3, 2),
#  ('juice', 'chips', 3, 1),
#  ('juice', 'cookies', 3, 2),
#  ('juice', 'eggs', 3, 1),
#  ('juice', 'milk', 3, 3),
#  ('milk', 'chips', 4, 1),
#  ('milk', 'cookies', 4, 2),
#  ('milk', 'eggs', 4, 2),
#  ('milk', 'juice', 4, 3)]

# %% [markdown]
# #### Add check for specified confidence to get final result

# %%
# %%sql
# select T1.item as LHS, T2.item as RHS
# from Shop T1, Shop T2, Frequent F
# where T1.item = F.item
# and T1.TID = T2.TID
# and T1.item != T2.item
# group by T1.item, T2.item
# having 1.0*count() / F.numtrans > :confidence
# Out:
#  * sqlite://
# Done.
# [('eggs', 'milk'), ('juice', 'cookies'), ('juice', 'milk'), ('milk', 'juice')]

# %% [markdown]
# ### Association rules with two items on the left-hand side

# %%
support = .5
confidence = .5
print(support, confidence)
# Out:
# 0.5 0.5

# %% [markdown]
# #### First compute frequent item-sets of two items with specified support, as candidate left-hand sides of assocation rules. Save in table "Frequent" along with number of transactions

# %%
# %%sql
# drop table if exists Frequent;
# create table Frequent(item1, item2, numtrans);
# insert into Frequent
# select T1.item, T2.item, count()
# from Shop T1, Shop T2
# where T1.TID = T2.TID
# and T1.item < T2.item
# group by T1.item, T2.item
# having 1.0*count() / (select count(distinct TID) from Shop) > :support;
# select * from Frequent
# Out:
#  * sqlite://
# Done.
# Done.
# 1 rows affected.
# Done.
# [('juice', 'milk', 3)]

# %% [markdown]
# #### All triples with frequent left-hand side, number of transactions for left-hand side, and number of transactions for all three

# %%
# %%sql
# select T1.item as LHS1, T2.item as LHS2, T3.item as RHS, F.numtrans, count()
# from Shop T1, Shop T2, Shop T3, Frequent F
# where T1.item = F.item1 and T2.item = F.item2
# and T1.TID = T2.TID and T2.TID = T3.TID
# and T1.item != T2.item and T2.item != T3.item and T1.item != T3.item
# group by T1.item, T2.item, T3.item
# Out:
#  * sqlite://
# Done.
# [('juice', 'milk', 'chips', 3, 1),
#  ('juice', 'milk', 'cookies', 3, 2),
#  ('juice', 'milk', 'eggs', 3, 1)]

# %% [markdown]
# #### Add check for specified confidence to get final result

# %%
# %%sql
# select T1.item as LHS1, T2.item as LHS2, T3.item as RHS
# from Shop T1, Shop T2, Shop T3, Frequent F
# where T1.item = F.item1 and T2.item = F.item2
# and T1.TID = T2.TID and T2.TID = T3.TID
# and T1.item != T2.item and T2.item != T3.item and T1.item != T3.item
# group by T1.item, T2.item, T3.item
# having 1.0*count() / F.numtrans > :confidence
# Out:
#  * sqlite://
# Done.
# [('juice', 'milk', 'cookies')]

# %% [markdown]
# ## Shopping dataset - association rules with lift instead of confidence

# %% [markdown]
# #### Compute overall frequency of each item -- needed for lift calculation

# %%
# %%sql
# select item, 1.0*count() / (select count(distinct TID) from Shop)
# from Shop
# group by item
# Out:
#  * sqlite://
# Done.
# [('chips', 0.4),
#  ('cookies', 0.4),
#  ('eggs', 0.6),
#  ('juice', 0.6),
#  ('milk', 0.8)]

# %% [markdown]
# #### Do the same query but save the result in a table called "ItemFreq"

# %%
# %%sql
# drop table if exists ItemFreq;
# create table ItemFreq(item, freq);
# insert into ItemFreq
# select item, 1.0*count() / (select count(distinct TID) from Shop)
# from Shop
# group by item;
# select * from ItemFreq
# Out:
#  * sqlite://
# Done.
# Done.
# 5 rows affected.
# Done.
# [('chips', 0.4),
#  ('cookies', 0.4),
#  ('eggs', 0.6),
#  ('juice', 0.6),
#  ('milk', 0.8)]

# %% [markdown]
# ### Association rules with one item on the left-hand side

# %%
support = .5
print(support)
# Out:
# 0.5

# %% [markdown]
# #### First compute frequent item-sets of one item with specified support, as candidate left-hand sides of assocation rules. Save in table "Frequent" along with number of transactions.

# %%
# %%sql
# drop table if exists Frequent;
# create table Frequent(item, numtrans);
# insert into Frequent
# select item, count()
# from Shop
# group by item
# having 1.0*count() / (select count(distinct TID) from Shop) > :support;
# select * from Frequent
# Out:
#  * sqlite://
# Done.
# Done.
# 3 rows affected.
# Done.
# [('eggs', 3), ('juice', 3), ('milk', 4)]

# %% [markdown]
# #### All pairs with frequent left-hand side, number of transactions for left-hand side, and number of transactions for both

# %%
# %%sql
# select T1.item as LHS, T2.item as RHS, F.numtrans, count()
# from Shop T1, Shop T2, Frequent F
# where T1.item = F.item
# and T1.TID = T2.TID
# and T1.item != T2.item
# group by T1.item, T2.item
# Out:
#  * sqlite://
# Done.
# [('eggs', 'chips', 3, 1),
#  ('eggs', 'juice', 3, 1),
#  ('eggs', 'milk', 3, 2),
#  ('juice', 'chips', 3, 1),
#  ('juice', 'cookies', 3, 2),
#  ('juice', 'eggs', 3, 1),
#  ('juice', 'milk', 3, 3),
#  ('milk', 'chips', 4, 1),
#  ('milk', 'cookies', 4, 2),
#  ('milk', 'eggs', 4, 2),
#  ('milk', 'juice', 4, 3)]

# %% [markdown]
# #### Add check for lift > 1 to get final result

# %%
# %%sql
# select T1.item as LHS, T2.item as RHS, (1.0*count() / F.numtrans) / I.freq as lift
# from Shop T1, Shop T2, Frequent F, ItemFreq I
# where T1.item = F.item
# and T1.TID = T2.TID
# and T2.item = I.item
# and T1.item != T2.item
# group by T1.item, T2.item
# having (1.0*count() / F.numtrans) / I.freq > 1
# Out:
#  * sqlite://
# Done.
# [('juice', 'cookies', 1.6666666666666665),
#  ('juice', 'milk', 1.25),
#  ('milk', 'cookies', 1.25),
#  ('milk', 'juice', 1.25)]

# %% [markdown]
# ### Association rules with two items on the left-hand side

# %%
support = .5
print(support)
# Out:
# 0.5

# %% [markdown]
# #### First compute frequent item-sets of two items with specified support, as candidate left-hand sides of assocation rules. Save in table "Frequent" along with number of transactions

# %%
# %%sql
# drop table if exists Frequent;
# create table Frequent(item1, item2, numtrans);
# insert into Frequent
# select T1.item, T2.item, count()
# from Shop T1, Shop T2
# where T1.TID = T2.TID
# and T1.item < T2.item
# group by T1.item, T2.item
# having 1.0*count() / (select count(distinct TID) from Shop) > :support;
# select * from Frequent
# Out:
#  * sqlite://
# Done.
# Done.
# 1 rows affected.
# Done.
# [('juice', 'milk', 3)]

# %% [markdown]
# #### All triples with frequent left-hand side, number of transactions for left-hand side, and number of transactions for all three

# %%
# %%sql
# select T1.item as LHS1, T2.item as LHS2, T3.item as RHS, F.numtrans, count()
# from Shop T1, Shop T2, Shop T3, Frequent F
# where T1.item = F.item1 and T2.item = F.item2
# and T1.TID = T2.TID and T2.TID = T3.TID
# and T1.item != T2.item and T2.item != T3.item and T1.item != T3.item
# group by T1.item, T2.item, T3.item
# Out:
#  * sqlite://
# Done.
# [('juice', 'milk', 'chips', 3, 1),
#  ('juice', 'milk', 'cookies', 3, 2),
#  ('juice', 'milk', 'eggs', 3, 1)]

# %% [markdown]
# #### Add check for lift > 1 to get final result

# %%
# %%sql
# select T1.item as LHS1, T2.item as LHS2, T3.item as RHS, (1.0*count() / F.numtrans) / I.freq as lift
# from Shop T1, Shop T2, Shop T3, Frequent F, ItemFreq I
# where T1.item = F.item1 and T2.item = F.item2
# and T1.TID = T2.TID and T2.TID = T3.TID and T3.item = I.item
# and T1.item != T2.item and T2.item != T3.item and T1.item != T3.item
# group by T1.item, T2.item, T3.item
# having (1.0*count() / F.numtrans) / I.freq > 1
# Out:
#  * sqlite://
# Done.
# [('juice', 'milk', 'cookies', 1.6666666666666665)]

# %% [markdown]
# ### <font color = 'green'>**Your Turn - Movies dataset association rules**</font>

# %% [markdown]
# #### Mine for association rules in the Movies dataset with three items on the left-hand side. Find support and confidence thresholds (need not be the same) so the number of association rules is more than 10 but less than 20.

# %%
support = 0.03
confidence = 0.6315
print(support, confidence)
# Out:
# 0.03 0.6315

# %%
# %%sql
# drop table if exists Frequent;
# create table Frequent(item1, item2, item3, numtrans);
# insert into Frequent
# select T1.item, T2.item, T3.item, count()
# from Movies T1, Movies T2, Movies T3
# where T1.TID = T2.TID and T2.TID = T3.TID
# and T1.item < T2.item and T2.item < T3.item
# group by T1.item, T2.item, T3.item
# having 1.0*count() / (select count(distinct TID) from Movies) > :support;
# select * from Frequent
# Out:
#  * sqlite://
# Done.
# Done.
# 14 rows affected.
# Done.
# [('Big Hero 6', 'Boyhood', 'Gone Girl', 56),
#  ('Big Hero 6', 'Boyhood', 'The Imitation Game', 57),
#  ('Big Hero 6', 'Fury', 'Gone Girl', 43),
#  ('Big Hero 6', 'Fury', 'The Imitation Game', 44),
#  ('Big Hero 6', 'Gone Girl', 'Inside Out', 85),
#  ('Big Hero 6', 'Gone Girl', 'The Imitation Game', 119),
#  ('Big Hero 6', 'Inside Out', 'The Imitation Game', 102),
#  ('Boyhood', 'Fury', 'Gone Girl', 43),
#  ('Boyhood', 'Fury', 'The Imitation Game', 43),
#  ('Boyhood', 'Gone Girl', 'Inside Out', 54),
#  ('Boyhood', 'Gone Girl', 'The Imitation Game', 95),
#  ('Boyhood', 'Inside Out', 'The Imitation Game', 52),
#  ('Fury', 'Gone Girl', 'The Imitation Game', 70),
#  ('Gone Girl', 'Inside Out', 'The Imitation Game', 103)]

# %%
# %%sql
# select T1.item as LHS1, T2.item as LHS2, T3.item as LHS3, T4.item as RHS, F.numtrans, count()
# from Movies T1, Movies T2, Movies T3, Movies T4, Frequent F
# where T1.item = F.item1 and T2.item = F.item2 and T3.item = F.item3
# and T1.TID = T2.TID and T2.TID = T3.TID and T3.TID = T4.TID
# and T1.item != T2.item and T2.item != T3.item and T3.item != T4.item
# and T1.item != T3.item and T1.item != T4.item and T2.item != T4.item
# group by T1.item, T2.item, T3.item, T4.item
# having 1.0*count() / F.numtrans > :confidence
# Out:
#  * sqlite://
# Done.
# [('Big Hero 6', 'Boyhood', 'Gone Girl', 'The Imitation Game', 56, 46),
#  ('Big Hero 6', 'Boyhood', 'The Imitation Game', 'Gone Girl', 57, 46),
#  ('Big Hero 6', 'Fury', 'Gone Girl', 'Inside Out', 43, 29),
#  ('Big Hero 6', 'Fury', 'Gone Girl', 'The Imitation Game', 43, 36),
#  ('Big Hero 6', 'Fury', 'The Imitation Game', 'Boyhood', 44, 28),
#  ('Big Hero 6', 'Fury', 'The Imitation Game', 'Gone Girl', 44, 36),
#  ('Big Hero 6', 'Fury', 'The Imitation Game', 'Inside Out', 44, 28),
#  ('Big Hero 6', 'Gone Girl', 'Inside Out', 'The Imitation Game', 85, 59),
#  ('Boyhood', 'Fury', 'Gone Girl', 'The Imitation Game', 43, 39),
#  ('Boyhood', 'Fury', 'The Imitation Game', 'Big Hero 6', 43, 28),
#  ('Boyhood', 'Fury', 'The Imitation Game', 'Gone Girl', 43, 39),
#  ('Boyhood', 'Gone Girl', 'Inside Out', 'The Imitation Game', 54, 42),
#  ('Boyhood', 'Inside Out', 'The Imitation Game', 'Big Hero 6', 52, 35),
#  ('Boyhood', 'Inside Out', 'The Imitation Game', 'Gone Girl', 52, 42)]

# %% [markdown]
# #### Mine for association rules in the Movies dataset with three items on the left-hand side. Find support and lift thresholds so the number of association rules is more than 10 but less than 20.

# %%
support = 0.025
lift = 36
print(support, lift)
# Out:
# 0.025 36

# %%
# %%sql
# drop table if exists ItemFreq;
# create table ItemFreq(item, freq);
# insert into ItemFreq
# select item, 1.0*count() / (select count(distinct TID) from Movies)
# from Movies
# group by item;
# select * from ItemFreq
# Out:
#  * sqlite://
# Done.
# Done.
# 123 rows affected.
# Done.
# [('400 Days', 0.002170767004341534),
#  ('A Walk in the Woods', 0.000723589001447178),
#  ('About Alex', 0.005065123010130246),
#  ('Action Jackson', 0.000723589001447178),
#  ('American Ultra', 0.013024602026049204),
#  ('Annie', 0.004341534008683068),
#  ('Anti-Social', 0.000723589001447178),
#  ('Appropriate Behaviour', 0.001447178002894356),
#  ('Ascension', 0.002170767004341534),
#  ('Aziz Ansari: Live at Madison Square Garden', 0.000723589001447178),
#  ('Bad Asses on the Bayou', 0.000723589001447178),
#  ('Bad Country', 0.000723589001447178),
#  ('Batkid Begins', 0.000723589001447178),
#  ('Bears', 0.000723589001447178),
#  ('Beautiful Girl', 0.000723589001447178),
#  ('Before I Disappear', 0.005065123010130246),
#  ('Best of Enemies', 0.002170767004341534),
#  ('Big Eyes', 0.020984081041968163),
#  ('Big Hero 6', 0.28002894356005786),
#  ('Blind', 0.000723589001447178),
#  ('Boyhood', 0.1649782923299566),
#  ('Break Point', 0.000723589001447178),
#  ('Breathe', 0.000723589001447178),
#  ('Butterfly', 0.000723589001447178),
#  ('Calvary', 0.02604920405209841),
#  ('Camp Belvidere', 0.000723589001447178),
#  ('Carmina and Amen (Carmina y amÌ©n)', 0.000723589001447178),
#  ('Catch Hell', 0.000723589001447178),
#  ('Contracted: Phase II', 0.000723589001447178),
#  ('Copenhagen', 0.005065123010130246),
#  ('Court', 0.000723589001447178),
#  ('Crimes Against Humanity', 0.001447178002894356),
#  ('Cruel & Unusual', 0.001447178002894356),
#  ('Daawat-e-Ishq', 0.000723589001447178),
#  ('Dark Summer', 0.000723589001447178),
#  ('Deadly Virtues: Love.Honour.Obey.', 0.000723589001447178),
#  ('Dear White People', 0.006512301013024602),
#  ('Demonic', 0.001447178002894356),
#  ('Dum Laga Ke Haisha', 0.002170767004341534),
#  ('Eat', 0.000723589001447178),
#  ('Effie Gray', 0.000723589001447178),
#  ('Entertainment', 0.000723589001447178),
#  ('Exists', 0.000723589001447178),
#  ('Exposed', 0.000723589001447178),
#  ('Faith of Our Fathers', 0.001447178002894356),
#  ('Far from Men', 0.000723589001447178),
#  ('Final Girl', 0.000723589001447178),
#  ('Flowers in the Attic', 0.000723589001447178),
#  ('Force Majeure (Turist)', 0.01085383502170767),
#  ('Fury', 0.09985528219971057),
#  ('Gangster Payday', 0.000723589001447178),
#  ('Gett: The Trial of Viviane Amsalem', 0.002894356005788712),
#  ('Gone Girl', 0.42185238784370477),
#  ('Grace', 0.002170767004341534),
#  ('Grandma', 0.000723589001447178),
#  ("I'll See You in My Dreams", 0.000723589001447178),
#  ('In No Great Hurry: 13 Lessons in Life with Saul Leiter', 0.000723589001447178),
#  ('In Order of Disappearance (Kraftidioten)', 0.001447178002894356),
#  ('In the Heart of the Sea', 0.006512301013024602),
#  ('Inside Out', 0.3256150506512301),
#  ('Jim Gaffigan: Obsessed', 0.002170767004341534),
#  ('Justice League: Gods and Monsters', 0.00361794500723589),
#  ('Laggies', 0.012301013024602027),
#  ('Leviathan', 0.016642547033285094),
#  ('Listen Up Philip', 0.002894356005788712),
#  ('Louis C.K.: Live at The Comedy Store', 0.06512301013024602),
#  ('Love Me', 0.000723589001447178),
#  ('Magic Mike XXL', 0.005788712011577424),
#  ('Magic in the Moonlight', 0.01808972503617945),
#  ('Man Up', 0.005065123010130246),
#  ('Merchants of Doubt', 0.001447178002894356),
#  ('Mr. Peabody & Sherman', 0.006512301013024602),
#  ('National Gallery', 0.000723589001447178),
#  ('No No: A Dockumentary', 0.001447178002894356),
#  ('Outcast', 0.000723589001447178),
#  ("PAY 2 PLAY: Democracy's High Stakes", 0.000723589001447178),
#  ('Preggoland', 0.000723589001447178),
#  ('Rage', 0.001447178002894356),
#  ('Raised by Wolves', 0.000723589001447178),
#  ('Samba', 0.002894356005788712),
#  ('Scusate se esisto!', 0.000723589001447178),
#  ('Self/less', 0.01085383502170767),
#  ("She's Funny That Way", 0.00361794500723589),
#  ('Sinister 2', 0.000723589001447178),
#  ('Sisters', 0.00723589001447178),
#  ('Skin Trade', 0.000723589001447178),
#  ('Stage Fright', 0.001447178002894356),
#  ('Steve Jobs: The Man in the Machine', 0.005065123010130246),
#  ('Strangerland', 0.002170767004341534),
#  ('Tanu Weds Manu Returns', 0.000723589001447178),
#  ('Teenage Mutant Ninja Turtles', 0.028219971056439943),
#  ('The Best of Me', 0.00361794500723589),
#  ('The Big Short', 0.023878437047756874),
#  ('The Christmas Secret', 0.000723589001447178),
#  ("The Crow's Nest", 0.000723589001447178),
#  ('The Divine Move', 0.001447178002894356),
#  ('The Fault in Our Stars', 0.08031837916063676),
#  ('The Green Prince', 0.000723589001447178),
#  ('The Humbling', 0.001447178002894356),
#  ('The Hunger Games: Mockingjay - Part 2', 0.04703328509406657),
#  ('The Imitation Game', 0.48986975397973953),
#  ('The Little Death', 0.006512301013024602),
#  ('The Little Rascals Save the Day', 0.000723589001447178),
#  ('The Mend', 0.000723589001447178),
#  ('The Price of Gold', 0.001447178002894356),
#  ('The Treasure', 0.000723589001447178),
#  ('The Unexpected Love', 0.000723589001447178),
#  ('The Vatican Tapes', 0.000723589001447178),
#  ('The Voices', 0.015195369030390739),
#  ('The Wonders', 0.000723589001447178),
#  ('Time Out of Mind', 0.000723589001447178),
#  ('Transformers: Age of Extinction', 0.049927641099855286),
#  ('Turks & Caicos', 0.001447178002894356),
#  ('Unexpected', 0.001447178002894356),
#  ('V/H/S: Viral', 0.002894356005788712),
#  ('Victor Frankenstein', 0.002170767004341534),
#  ('Viy', 0.000723589001447178),
#  ('Wanderers', 0.002170767004341534),
#  ('Web Junkie', 0.000723589001447178),
#  ('Welcome to Leith', 0.001447178002894356),
#  ('Whitey: United States of America v. James J. Bulger', 0.000723589001447178),
#  ('Wild Card', 0.00361794500723589),
#  ('Wild Tales', 0.049204052098408106)]

# %%
# %%sql
# drop table if exists Frequent;
# create table Frequent(item1, item2, item3, numtrans);
# insert into Frequent
# select T1.item, T2.item, T3.item, count()
# from Movies T1, Movies T2, Movies T3
# where T1.TID = T2.TID and T2.TID = T3.TID
# and T1.item < T2.item and T2.item < T3.item
# group by T1.item, T2.item, T3.item
# having 1.0*count() / (select count(distinct TID) from Movies) > :support;
# select * from Frequent
# Out:
#  * sqlite://
# Done.
# Done.
# 19 rows affected.
# Done.
# [('Big Hero 6', 'Boyhood', 'Gone Girl', 56),
#  ('Big Hero 6', 'Boyhood', 'Inside Out', 39),
#  ('Big Hero 6', 'Boyhood', 'The Imitation Game', 57),
#  ('Big Hero 6', 'Fury', 'Gone Girl', 43),
#  ('Big Hero 6', 'Fury', 'The Imitation Game', 44),
#  ('Big Hero 6', 'Gone Girl', 'Inside Out', 85),
#  ('Big Hero 6', 'Gone Girl', 'The Imitation Game', 119),
#  ('Big Hero 6', 'Inside Out', 'The Imitation Game', 102),
#  ('Boyhood', 'Fury', 'Gone Girl', 43),
#  ('Boyhood', 'Fury', 'The Imitation Game', 43),
#  ('Boyhood', 'Gone Girl', 'Inside Out', 54),
#  ('Boyhood', 'Gone Girl', 'The Imitation Game', 95),
#  ('Boyhood', 'Inside Out', 'The Imitation Game', 52),
#  ('Fury', 'Gone Girl', 'Inside Out', 40),
#  ('Fury', 'Gone Girl', 'The Imitation Game', 70),
#  ('Fury', 'Inside Out', 'The Imitation Game', 39),
#  ('Gone Girl', 'Inside Out', 'The Imitation Game', 103),
#  ('Gone Girl', 'The Fault in Our Stars', 'The Imitation Game', 35),
#  ('Gone Girl', 'The Imitation Game', 'Wild Tales', 35)]

# %%
# %%sql
# select T1.item as LHS1, T2.item as LHS2, T3.item as LHS3, T4.item as RHS,
#        (1.0*count() / F.numtrans) / I.freq as lift
# from Movies T1, Movies T2, Movies T3, Movies T4, Frequent F, ItemFreq I
# where T1.item = F.item1 and T2.item = F.item2 and T3.item = F.item3
# and T1.TID = T2.TID and T2.TID = T3.TID and T3.TID = T4.TID
# and T4.item = I.item
# and T1.item != T2.item and T2.item != T3.item and T3.item != T4.item
# and T1.item != T3.item and T1.item != T4.item and T2.item != T4.item
# group by T1.item, T2.item, T3.item, T4.item
# having (1.0*count() / F.numtrans) / I.freq > :lift
# Out:
#  * sqlite://
# Done.
# [('Gone Girl', 'The Fault in Our Stars', 'The Imitation Game', 'Action Jackson', 39.48571428571429),
#  ('Gone Girl', 'The Fault in Our Stars', 'The Imitation Game', 'Breathe', 39.48571428571429),
#  ('Gone Girl', 'The Fault in Our Stars', 'The Imitation Game', 'Catch Hell', 39.48571428571429),
#  ('Gone Girl', 'The Fault in Our Stars', 'The Imitation Game', 'Court', 39.48571428571429),
#  ('Gone Girl', 'The Fault in Our Stars', 'The Imitation Game', "I'll See You in My Dreams", 39.48571428571429),
#  ('Gone Girl', 'The Fault in Our Stars', 'The Imitation Game', 'Outcast', 39.48571428571429),
#  ('Gone Girl', 'The Fault in Our Stars', 'The Imitation Game', 'Time Out of Mind', 39.48571428571429),
#  ('Gone Girl', 'The Imitation Game', 'Wild Tales', 'Entertainment', 39.48571428571429),
#  ('Gone Girl', 'The Imitation Game', 'Wild Tales', 'Far from Men', 39.48571428571429),
#  ('Gone Girl', 'The Imitation Game', 'Wild Tales', "I'll See You in My Dreams", 39.48571428571429),
#  ('Gone Girl', 'The Imitation Game', 'Wild Tales', 'Outcast', 39.48571428571429),
#  ('Gone Girl', 'The Imitation Game', 'Wild Tales', 'The Wonders', 39.48571428571429),
#  ('Gone Girl', 'The Imitation Game', 'Wild Tales', 'Time Out of Mind', 39.48571428571429)]
